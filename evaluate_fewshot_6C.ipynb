# %%
import pandas as pd

csv_file_onek_GLASSO = 'evaluation/fewshots/6C_paddle_woverlap_False_adaptatif_1000%_GLASSO_analysis.csv'
csv_file_overlap_onek_GLASSO = 'evaluation/fewshots/6C_paddle_woverlap_True_adaptatif_1000%_GLASSO_analysis.csv'
csv_file_onek_NONE = 'evaluation/fewshots/6C_paddle_woverlap_False_adaptatif_1000%_NONE_analysis.csv'
csv_file_overlap_onek_NONE = 'evaluation/fewshots/6C_paddle_woverlap_True_adaptatif_1000%_NONE_analysis.csv'
csv_file_overlap_fivek_GLASSO = 'evaluation/fewshots/6C_paddle_woverlap_True_adaptatif_5000%_GLASSO_analysis.csv'
csv_file_overlap_paper_GLASSO = 'evaluation/fewshots/6C_paddle_woverlap_True_1250_GLASSO_analysis.csv'

df_onek_GLASSO = pd.read_csv(csv_file_onek_GLASSO)
df_overlap_onek_GLASSO = pd.read_csv(csv_file_overlap_onek_GLASSO)
df_onek_NONE = pd.read_csv(csv_file_onek_NONE)
df_overlap_onek_NONE = pd.read_csv(csv_file_overlap_onek_NONE)
df_overlap_fivek_GLASSO = pd.read_csv(csv_file_overlap_fivek_GLASSO)
df_overlap_paper_GLASSO = pd.read_csv(csv_file_overlap_paper_GLASSO)

# %%
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
plt.figure(figsize=(13, 8))
plt.plot(df_onek_GLASSO['n_shots'], df_onek_GLASSO['accuracies'], marker='o', linestyle='-', color='b', label='PADDLE-Cov 1000%')
plt.plot(df_overlap_onek_GLASSO['n_shots'], df_overlap_onek_GLASSO['accuracies'], marker='o', linestyle='-', color='r', label='PADDLE-Cov 1000% w overlap')
plt.plot(df_onek_NONE['n_shots'], df_onek_NONE['accuracies'], marker='o', linestyle='-', color='g', label='PADDLE 1000%')
plt.plot(df_overlap_onek_NONE['n_shots'], df_overlap_onek_NONE['accuracies'], marker='o', linestyle='-', color='y', label='PADDLE 1000% w overlap')
plt.plot(df_overlap_fivek_GLASSO['n_shots'], df_overlap_fivek_GLASSO['accuracies'], marker='o', linestyle='-', color='c', label='PADDLE-Cov 5000% w overlap')
plt.plot(df_overlap_paper_GLASSO['n_shots'], df_overlap_paper_GLASSO['accuracies'], marker='o', linestyle='-', color='m', label='PADDLE-Cov 1250 w overlap')

plt.xscale('log')
plt.xlabel('n_shots')
plt.ylabel('accuracy')
plt.title('Fewshots accuracies analysis')
plt.legend()
#plt.savefig('evaluation/fewshots/6C_paddle_accuracy_analysis.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
plt.figure(figsize=(13, 8))
plt.plot(df_onek_GLASSO['n_shots'], df_onek_GLASSO['f1_macro_scores'], marker='o', linestyle='-', color='b', label='PADDLE-Cov 1000%')
plt.plot(df_overlap_onek_GLASSO['n_shots'], df_overlap_onek_GLASSO['f1_macro_scores'], marker='o', linestyle='-', color='r', label='PADDLE-Cov 1000% w overlap')
plt.plot(df_onek_NONE['n_shots'], df_onek_NONE['f1_macro_scores'], marker='o', linestyle='-', color='g', label='PADDLE 1000%')
plt.plot(df_overlap_onek_NONE['n_shots'], df_overlap_onek_NONE['f1_macro_scores'], marker='o', linestyle='-', color='y', label='PADDLE 1000% w overlap')
plt.plot(df_overlap_fivek_GLASSO['n_shots'], df_overlap_fivek_GLASSO['f1_macro_scores'], marker='o', linestyle='-', color='c', label='PADDLE-Cov 5000% w overlap')
plt.plot(df_overlap_paper_GLASSO['n_shots'], df_overlap_paper_GLASSO['f1_macro_scores'], marker='o', linestyle='-', color='m', label='PADDLE-Cov 1250 w overlap')

plt.xscale('log')
plt.xlabel('n_shots')
plt.ylabel('f1_macro')
plt.title('Fewshots f1_macro_scores analysis')
plt.legend()
#plt.savefig('evaluation/fewshots/6C_paddle_f1_macro_analysis.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame
plt.figure(figsize=(13, 8))
plt.plot(df_onek_GLASSO['n_shots'], df_onek_GLASSO['f1_weighted_scores'], marker='o', linestyle='-', color='b', label='PADDLE-Cov 1000%')
plt.plot(df_overlap_onek_GLASSO['n_shots'], df_overlap_onek_GLASSO['f1_weighted_scores'], marker='o', linestyle='-', color='r', label='PADDLE-Cov 1000% w overlap')
plt.plot(df_onek_NONE['n_shots'], df_onek_NONE['f1_weighted_scores'], marker='o', linestyle='-', color='g', label='PADDLE 1000%')
plt.plot(df_overlap_onek_NONE['n_shots'], df_overlap_onek_NONE['f1_weighted_scores'], marker='o', linestyle='-', color='y', label='PADDLE 1000% w overlap')
plt.plot(df_overlap_fivek_GLASSO['n_shots'], df_overlap_fivek_GLASSO['f1_weighted_scores'], marker='o', linestyle='-', color='c', label='PADDLE-Cov 5000% w overlap')
plt.plot(df_overlap_paper_GLASSO['n_shots'], df_overlap_paper_GLASSO['f1_weighted_scores'], marker='o', linestyle='-', color='m', label='PADDLE-Cov 1250 w overlap')

plt.xscale('log')
plt.xlabel('n_shots')
plt.ylabel('f1_weighted')
plt.title('Fewshots f1_weighted_scores analysis')
plt.legend()
#plt.savefig('evaluation/fewshots/6C_paddle_f1_weighted_analysis.png')
plt.show()
