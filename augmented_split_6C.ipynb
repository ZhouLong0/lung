# %%
import pandas as pd

# %%
df_6c = pd.read_csv('data/dataframes/df_train_6C_augmented.csv')
df_6c
# Out:
#        Patient lame                     patch       classe  label dataset
# 0            7    R          R_7_A (3844).jpg  Réactionnel      0   train  \
# 1          231    R       R_231_A (11)_VF.jpg  Réactionnel      0   train
# 2          231    R       R_231_A (16)_VF.jpg  Réactionnel      0   train
# 3          231    R         R_231_A (263).jpg  Réactionnel      0   train
# 4            7    R       R_7_A (2525)_VF.jpg  Réactionnel      0   train
# ...        ...  ...                       ...          ...    ...     ...
# 66644      169   Fo        Fo_169_A (340).jpg       Foetal      5   train
# 66645      169    A          A_169_A (38).jpg     Acinaire      5   train
# 66646      169   Fo  Fo_169_A (193)_rot45.jpg       Foetal      5   train
# 66647      169   Fo        Fo_169_A (300).jpg       Foetal      5   train
# 66648      169   Fo     Fo_169_A (225)_HF.jpg       Foetal      5   train
#
#       TetraClass
# 0              P
# 1              P
# 2              P
# ...

# %%
df_7c = pd.read_csv('data/dataframes/df_train_7C_augmented.csv')
df_7c
# Out:
#        Patient lame                  patch       classe  label dataset
# 0            7    R     R_7_A (491)_VF.jpg  Réactionnel      0   train  \
# 1            7    R    R_7_A (3464)_VF.jpg  Réactionnel      0   train
# 2            7    R        R_7_A (177).jpg  Réactionnel      0   train
# 3            7    R    R_7_A (3329)_VF.jpg  Réactionnel      0   train
# 4            7    R    R_7_A (1843)_VF.jpg  Réactionnel      0   train
# ...        ...  ...                    ...          ...    ...     ...
# 66644      231    S   S_231_A (894)_HF.jpg       Solide      6   train
# 66645      231    S  S_231_A (1640)_VF.jpg       Solide      6   train
# 66646      231    S   S_231_A (176)_VF.jpg       Solide      6   train
# 66647      231    S  S_231_A (1659)_VF.jpg       Solide      6   train
# 66648      231    S  S_231_A (1052)_VF.jpg       Solide      6   train
#
#       TetraClass
# 0              P
# 1              P
# 2              P
# 3              P
# 4              P
# ...

# %%
df_7c_test = pd.read_csv('data/dataframes/df_test_7C_augmented.csv')
df_7c_test
# Out:
#        Patient lame                     patch                classe  label
# 0          398    R     R_398_A (1468)_HF.jpg           Réactionnel      0  \
# 1          398    R      R_398_A (203)_HF.jpg           Réactionnel      0
# 2          398    R     R_398_A (1100)_VF.jpg           Réactionnel      0
# 3          398    R         R_398_A (788).jpg           Réactionnel      0
# 4          247    R         R_247_A (549).jpg           Réactionnel      0
# ...        ...  ...                       ...                   ...    ...
# 16720      247   Gc       Gc_247_A (1328).jpg  Glandulaire complexe      6
# 16721      398   Gc       Gc_398_A (4)_HF.jpg  Glandulaire complexe      6
# 16722        2    B  2_B_row_70_col_17_VF.jpg  Glandulaire complexe      6
# 16723      247   Gc    Gc_247_A (1386)_VF.jpg  Glandulaire complexe      6
# 16724      247   Gc    Gc_247_A (1360)_VF.jpg  Glandulaire complexe      6
#
#       dataset TetraClass
# 0        test          P
# ...

# %%
df_6c_test = pd.read_csv('data/dataframes/df_test_6C_augmented.csv')
df_6c_test
# Out:
#        Patient lame                           patch       classe  label
# 0          398    R            R_398_A (145)_HF.jpg  Réactionnel      0  \
# 1          247    R            R_247_A (461)_VF.jpg  Réactionnel      0
# 2          247    R            R_247_A (460)_HF.jpg  Réactionnel      0
# 3          247    R               R_247_A (537).jpg  Réactionnel      0
# 4          247    R            R_247_A (513)_VF.jpg  Réactionnel      0
# ...        ...  ...                             ...          ...    ...
# 16720      133    A    133_A_row_374_col_243_HF.jpg    Lépidique      5
# 16721      133    B      133_B_row_57_col_97_VF.jpg    Lépidique      5
# 16722      133    A    133_A_row_377_col_240_HF.jpg    Lépidique      5
# 16723      133    A       133_A_row_381_col_209.jpg    Lépidique      5
# 16724      133    B  133_B_row_39_col_92 (1)_HF.jpg    Lépidique      5
#
#       dataset TetraClass
# 0        test          P
# 1        test          P
# ...
